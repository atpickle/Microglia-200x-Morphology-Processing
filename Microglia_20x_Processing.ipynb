# %% [markdown]
# Conduct microglia image processing on 200x images

# %%
from Microglia_Processing import *

# %%
folder_path = '/Users/allisonpickle/Desktop/251120_NoraLPSPlate/Microglia'

# %% [markdown]
# Before use: Isolate microglia channel into a new folder for processing

# %% [markdown]
# Autocrop microglia of interest for morphology assessment

# %%
Isolate_Microglia(folder_path, padding=20, min_size_microns=250)
# Out:
# Randomly selected 5 objects out of 11 total objects.
# Saved cropped _C_0 image: /Users/allisonpickle/Desktop/251120_NoraLPSPlate/Microglia/Isolated microglia/Tri_5ugLPS_04_1_C_0.tiff
# Saved cropped _C_0 image: /Users/allisonpickle/Desktop/251120_NoraLPSPlate/Microglia/Isolated microglia/Tri_5ugLPS_04_2_C_0.tiff
# Skipping object 3 - touching the edge of the image.
# Saved cropped _C_0 image: /Users/allisonpickle/Desktop/251120_NoraLPSPlate/Microglia/Isolated microglia/Tri_5ugLPS_04_4_C_0.tiff
# Saved cropped _C_0 image: /Users/allisonpickle/Desktop/251120_NoraLPSPlate/Microglia/Isolated microglia/Tri_5ugLPS_04_5_C_0.tiff
# Randomly selected 5 objects out of 20 total objects.
# Saved cropped _C_0 image: /Users/allisonpickle/Desktop/251120_NoraLPSPlate/Microglia/Isolated microglia/Tri_5ugLPS_05_1_C_0.tiff
# Saved cropped _C_0 image: /Users/allisonpickle/Desktop/251120_NoraLPSPlate/Microglia/Isolated microglia/Tri_5ugLPS_05_2_C_0.tiff
# ...

# %% [markdown]
# MEASURE MICROGLIA MORPHOLOGY

# %%
folder_path = '/Users/allisonpickle/Desktop/251120_NoraLPSPlate/Microglia/Isolated microglia'

# %%
Measure_Microglia_Morphology(folder_path)
# Out:
# Results exported to /Users/allisonpickle/Desktop/251120_NoraLPSPlate/Microglia/Isolated microglia/Perimeter_Area_ConvexHull_Circularity_AspectRoughness_Results.xlsx
# /Users/allisonpickle/Library/CloudStorage/Box-Box/0_Şeker Lab/CoPilot/Microglia_Processing.py:244: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   results_with_averages.loc[results_with_averages.duplicated(subset=["Base Name"]), [col + " (Avg)" for col in numeric_columns]] = ""
# /Users/allisonpickle/Library/CloudStorage/Box-Box/0_Şeker Lab/CoPilot/Microglia_Processing.py:244: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
# ...

# %% [markdown]
# SHOLL ANALYSIS: Input is a folder of Microglia and DAPI channels

# %%
folder_path = '/Users/allisonpickle/Desktop/251120_NoraLPSPlate/All/Sholl Analysis/Isolated microglia'

# %% [markdown]
# AUTO CROP MICROGLIA AND DAPI

# %%
Isolate_Microglia_Sholl(folder_path, padding=20, min_size_microns=250)
# Out:
# Saved cropped _C_0 image: /Users/allisonpickle/Desktop/251120_NoraLPSPlate/All/Sholl Analysis/Isolated microglia/Isolated microglia/Tri_Ctrl_04_2_1_C_0.tiff
# Saved cropped _C_3 image: /Users/allisonpickle/Desktop/251120_NoraLPSPlate/All/Sholl Analysis/Isolated microglia/Isolated microglia/Tri_Ctrl_04_2_1_C_3.tiff
# Saved cropped _C_0 image: /Users/allisonpickle/Desktop/251120_NoraLPSPlate/All/Sholl Analysis/Isolated microglia/Isolated microglia/Tri_Ctrl_04_3_1_C_0.tiff
# Saved cropped _C_3 image: /Users/allisonpickle/Desktop/251120_NoraLPSPlate/All/Sholl Analysis/Isolated microglia/Isolated microglia/Tri_Ctrl_04_3_1_C_3.tiff
# Skipping object 1 - touching the edge of the image.
# Saved cropped _C_0 image: /Users/allisonpickle/Desktop/251120_NoraLPSPlate/All/Sholl Analysis/Isolated microglia/Isolated microglia/Tri_5ugLPS_01_2_1_C_0.tiff
# ...

# %%
folder_path = '/Users/allisonpickle/Desktop/251120_NoraLPSPlate/All/Sholl Analysis/Isolated microglia/Isolated microglia'

# %%
Colorize_Microglia_DAPI(folder_path, display_results=False, save_results=True)

# %% [markdown]
# input the original image to Sholl analysis, not threshold

# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
Process_Sholl(folder_path, output_folder_name="Sholl Analysis")

# %% [markdown]
# PHAGOCYTOSIS ANALYSIS: Expecting an input of a folder of C_1 and microglia channels

# %%
folder_path = '/Users/allisonpickle/Desktop/251120_NoraLPSPlate/Microglia'

# %%
Isolate_Microglia_GFAP(folder_path, padding=20, min_size_microns=250)

# %% [markdown]
# PHAGOCYTOSIS ANALYSIS. Measure mean gray value of the bead channel (C_1). Save output to an excel sheet.

# %%
input_folder = '/Users/allisonpickle/Desktop/250829_Phagocytosis/All/Isolated microglia_Beads_DAPI'

measure_mean_gray_value_c1(input_folder)
